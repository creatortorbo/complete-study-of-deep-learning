# %% [markdown]
# **Topics:**
#
#
#
# *   Reading an image file and converting it to a numpy array
# *   Resizing an image
# *   RGB to Grayscale conversion

# %% [markdown]
# **Libraries that can be used for image processing:**
#
# 1. matplotlib.image
#
# 2. Pillow
#
# 3. OpenCV (cv2)

# %%
# importing the image module from matplotlib library

import matplotlib.image as mpimg
from matplotlib import pyplot as plt

# %% [markdown]
# import matplotlib.image as mpimg
# <br>
# The image module provides functions to read, display, and manipulate images (like loading images from files into Python arrays).

# %%
# loading an image through matplotlib.image module

img = mpimg.imread('dog1.jpg')

# %%
# here we find the data type of the image 
type(img) # here it find the it is numpy array
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (333, 500, 3)

# %%
img
# Out:
# array([[[164, 103,  39],
#         [164, 103,  39],
#         [164, 104,  37],
#         ...,
#         [234, 218, 203],
#         [239, 223, 208],
#         [237, 222, 207]],
#
#        [[164, 103,  39],
#         [164, 103,  39],
#         [164, 104,  37],
#         ...,
#         [235, 220, 202],
#         [237, 222, 205],
#         [236, 221, 203]],
#
#        [[164, 103,  39],
#         [164, 103,  39],
#         [164, 104,  37],
#         ...,
#         [232, 217, 197],
#         [233, 218, 198],
#         [231, 216, 196]],
#
#        ...,
#
#        [[107,  70,  44],
#         [124,  87,  61],
#         [122,  85,  59],
#         ...,
#         [ 67,  50,  28],
#         [ 67,  50,  28],
#         [ 59,  42,  20]],
#
#        [[122,  85,  59],
#         [123,  86,  60],
#         [118,  82,  55],
#         ...,
#         [ 54,  37,  15],
#         [ 53,  36,  14],
#         [ 52,  35,  13]],
#
#        [[122,  85,  59],
#         [121,  84,  58],
#         [114,  77,  51],
#         ...,
#         [ 60,  43,  21],
#         [ 60,  43,  21],
#         [ 55,  38,  17]]], dtype=uint8)

# %%
# displaying the image from numpy array

img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using Pillow library

# %%
from PIL import Image

# %%
img = Image.open('dog1.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
# displaying the image from numpy array

img_res = mpimg.imread('dog_image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
img_res.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# **Converting RGB images to Grayscale image using OpenCV**

# %%
# importing OpenCV library
import cv2

# %%
img = cv2.imread('dog1.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (333, 500, 3)

# %%
grayscale_image = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (333, 500)

# %% [markdown]
# cv2.imshow() will display the image. But this will not be allowed in Google Colab.
#
# **from google.colab.patches import cv2_imshow**

# %%
plt.imshow(grayscale_image)
# plt.axis('off')  # Turn off axis labels
plt.show()

# %% [markdown]
# saveing the image for the grayscale

# %%
img_resized.save('grayscale_image.jpg')
