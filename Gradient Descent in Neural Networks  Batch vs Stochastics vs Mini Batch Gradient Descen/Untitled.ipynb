# %%
import numpy as np 
import pandas as pd 
import time

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df = df[['Age','EstimatedSalary','Purchased']]

# %%
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x.head()
# Out:
#    Age  EstimatedSalary
# 0   19            19000
# 1   35            20000
# 2   26            43000
# 3   27            57000
# 4   19            76000

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
# here it dowing the standing scalling 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[-1.78179743, -1.49004624],
#        [-0.25358736, -1.46068138],
#        [-1.11320552, -0.78528968],
#        [-1.01769239, -0.37418169],
#        [-1.78179743,  0.18375059],
#        [-1.01769239, -0.34481683],
#        [-1.01769239,  0.41866944],
#        [-0.54012675,  2.35674998],
#        [-1.20871865, -1.07893824],
#        [-0.25358736, -0.13926283],
#        [-1.11320552,  0.30121002],
#        [-1.11320552, -0.52100597],
#        [-1.6862843 ,  0.47739916],
#        [-0.54012675, -1.51941109],
#        [-1.87731056,  0.35993973],
#        [-0.82666613,  0.30121002],
#        [ 0.89257019, -1.3138571 ],
#        [ 0.70154394, -1.28449224],
#        [ 0.79705706, -1.22576253],
#        [ 0.98808332, -1.19639767],
#        [ 0.70154394, -1.40195167],
#        [ 0.89257019, -0.60910054],
#        [ 0.98808332, -0.84401939],
#        [ 0.70154394, -1.40195167],
#        [ 0.79705706, -1.37258681],
#        [ 0.89257019, -1.46068138],
#        [ 1.08359645, -1.22576253],
# ...

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_ size=0.2,random_state=2)

# %%
x_train.shape
# Out:
# (320, 2)

# %%
import tensorflow as tf 
from tensorflow  import keras 
from keras import Sequential 
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(10,activation = 'relu',input_dim = 2))
model.add(Dense(10,activation = 'relu'))
model.add(Dense(1,activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151 (604.00 B)
#  Trainable params: 151 (604.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# here using the (batch_size = 320 is for batch GD)
model.compile(loss= 'binary_crossentropy',metrics = ['accuracy'])
start = time.time()
history = model.fit(x_train,y_train,epochs = 10,batch_size = 320 )
print(time.time() - start)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 899ms/step - accuracy: 0.3469 - loss: 235.4069
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6531 - loss: 340.4693
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6531 - loss: 11.8309
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3469 - loss: 357.9512
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6531 - loss: 39.4443
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3469 - loss: 246.1207
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.6531 - loss: 80.2236
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3469 - loss: 156.6591
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6531 - loss: 123.7721
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.3469 - loss: 78.4128
# 1.230679988861084

# %%
# here using the (batch_size = 320 is for stochastic GD)
model.compile(loss= 'binary_crossentropy',metrics = ['accuracy'])
start = time.time()
history = model.fit(x_train,y_train,epochs = 10,batch_size = 1)
print(time.time() - start)
# Out:
# Epoch 1/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.4789 - loss: 191.3905
# Epoch 2/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - accuracy: 0.5435 - loss: 147.6426
# Epoch 3/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.5299 - loss: 152.8512
# Epoch 4/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.5749 - loss: 150.1917
# Epoch 5/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.5459 - loss: 149.9174
# Epoch 6/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.6446 - loss: 115.6084
# Epoch 7/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.5748 - loss: 126.8981
# Epoch 8/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.4619 - loss: 167.5053
# Epoch 9/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.4944 - loss: 138.0102
# Epoch 10/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.5795 - loss: 127.9410
# 3.4668896198272705
