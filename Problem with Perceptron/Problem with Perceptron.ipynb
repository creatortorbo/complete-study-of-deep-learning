# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt 
import seaborn as sns

# %%
# here we creating the data 
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1'] = [1,1,0,0]
or_data['input2'] = [1,0,1,0]
or_data['output'] = [1,1,1,0]

# %%
and_data['input1'] = [1,1,0,0]
and_data['input2'] = [1,0,1,0]
and_data['output'] = [1,0,0,0]

# %%
xor_data['input1'] = [1,1,0,0]
xor_data['input2'] = [1,0,1,0]
xor_data['output'] = [0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       0
# 2       0       1       0
# 3       0       0       0

# %%
sns.scatterplot(x = 'input1',y = 'input2', data = and_data,hue = 'output',s = 200)
plt.show()

# %%
or_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
sns.scatterplot(x = 'input1',y = 'input2', data = or_data,hue = 'output',s = 200)
plt.show()

# %%
xor_data
# Out:
#    input1  input2  output
# 0       1       1       0
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
sns.scatterplot(x = 'input1',y = 'input2', data = xor_data,hue = 'output',s = 200)
plt.show()

# %%
from sklearn.linear_model import Perceptron
clf1 = Perceptron()
clf2 = Perceptron()
clf3 = Perceptron()

# %%
clf1.fit(and_data.iloc[:,0:2].values, and_data.iloc[:,-1].values)
clf2.fit(or_data.iloc[:,0:2].values,or_data.iloc[:,-1].values)
clf3.fit(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
x = np.linspace(-1,1,5)
y = -x + 1

# %%
plt.plot(x,y)
sns.scatterplot(x = 'input1',y = 'input2', data = and_data,hue = 'output',s = 200)
plt.show()

# %%
clf2.coef_
# Out:
# array([[2., 2.]])

# %%
clf2.intercept_
# Out:
# array([-1.])

# %%
x1 = np.linspace(-1,1,5)
y1 = -x + 0.5

# %%
plt.plot(x1,y1)
sns.scatterplot(x = 'input1',y = 'input2', data = or_data,hue = 'output',s = 200)
plt.show()

# %%
clf3.coef_
# Out:
# array([[0., 0.]])

# %%
clf2.intercept_
# Out:
# array([-1.])

# %%
# here we dont have linear data than pPerceptron is not work it 
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values,clf = clf3,legend = 2)
plt.show()

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in x:\users\asus\anaconda3\lib\site-packages (from mlxtend) (1.11.4)
# Requirement already satisfied: numpy>=1.16.2 in x:\users\asus\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in x:\users\asus\anaconda3\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in x:\users\asus\anaconda3\lib\site-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in x:\users\asus\anaconda3\lib\site-packages (from mlxtend) (3.8.0)
# Requirement already satisfied: joblib>=0.13.2 in x:\users\asus\anaconda3\lib\site-packages (from mlxtend) (1.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in x:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in x:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in x:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in x:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in x:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in x:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in x:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in x:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in x:\users\asus\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in x:\users\asus\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in x:\users\asus\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in x:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.1-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.4 MB 435.7 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/1.4 MB 770.8 kB/s eta 0:00:02
#    -- ------------------------------------- 0.1/1.4 MB 655.4 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.4 MB 821.4 kB/s eta 0:00:02
#    ------- -------------------------------- 0.3/1.4 MB 1.1 MB/s eta 0:00:02
#    ------- -------------------------------- 0.3/1.4 MB 1.1 MB/s eta 0:00:02
#    --------- ------------------------------ 0.3/1.4 MB 1.1 MB/s eta 0:00:02
#    ---------- ----------------------------- 0.4/1.4 MB 1.0 MB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.4 MB 1.1 MB/s eta 0:00:01
#    -------------- ------------------------- 0.5/1.4 MB 1.1 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.4 MB 1.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.6/1.4 MB 1.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.6/1.4 MB 1.0 MB/s eta 0:00:01
#    ------------------ --------------------- 0.7/1.4 MB 1.1 MB/s eta 0:00:01
#    -------------------- ------------------- 0.7/1.4 MB 1.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.4 MB 1.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.4 MB 1.1 MB/s eta 0:00:01
#    ------------------------- -------------- 0.9/1.4 MB 1.0 MB/s eta 0:00:01
#    ------------------------- -------------- 0.9/1.4 MB 1.1 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.4 MB 1.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.4 MB 1.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.1/1.4 MB 1.0 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.4 MB 1.0 MB/s eta 0:00:01
#    ------------------------------- -------- 1.1/1.4 MB 1.0 MB/s eta 0:00:01
#    -------------------------------- ------- 1.2/1.4 MB 1.0 MB/s eta 0:00:01
#    --------------------------------- ------ 1.2/1.4 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.2/1.4 MB 1.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.4 MB 999.2 kB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.4 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.4 MB 987.1 kB/s eta 0:00:01
#    -------------------------------------- - 1.4/1.4 MB 997.8 kB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 1.0 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.1
